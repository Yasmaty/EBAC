# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Repita os mesmos passos feitos em aula, 
#    mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.

r_mun_rj = requests.get(
    'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')
r_mun_rj.status_code
# Out:
# 200

# %%
df_mun_rj = pd.DataFrame(r_mun_rj.json()['items'])
df_mun_rj
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0         15132        Município  Santa Vitória do Palmar   4317301  RS
# 1         16977        Município             Major Vieira   4210308  SC
# 2         15193        Município                   Loanda   4113502  PR
# 3          9178        Município    São José do Rio Preto   3549805  SP
# 4         10334        Município                   Pompéu   3152006  MG
# ...         ...              ...                      ...       ...  ..
# 4995       8775        Município          Salto do Lontra   4123006  PR
# 4996       8800        Município                    Iporá   5210208  GO
# 4997      12902        Município                 Alexânia   5200308  GO
# 4998      14294        Município            Rio das Antas   4214409  SC
# 4999      14333        Município                   Esteio   4307708  RS
#
#      num_pvl        status          num_processo        data_protocolo  \
# 0       None      Deferido  19406.000145/2007-51  2007-06-14T03:00:00Z
# 1       None      Deferido  19406.000389/2007-33  2007-10-08T03:00:00Z
# 2       None      Deferido  19406.000152/2005-91  2006-03-29T03:00:00Z
# 3       None      Deferido  17944.000919/2014-50  2014-07-14T03:00:00Z
# 4       None      Deferido  17944.001173/2013-11  2014-03-14T03:00:00Z
# ...      ...           ...                   ...                   ...
# 4995    None      Deferido  17944.000839/2013-13  2013-08-21T03:00:00Z
# 4996    None  Regularizado  17944.000843/2009-03  2023-07-28T03:00:00Z
# 4997    None     Arquivado  17944.001845/2006-69  2007-07-02T03:00:00Z
# 4998    None      Deferido  19406.000052/2004-83  2004-02-27T03:00:00Z
# 4999    None      Deferido  19406.000056/2007-12  2007-07-18T03:00:00Z
#
#                     tipo_operacao  \
# 0     Operação contratual interna
# 1     Operação contratual interna
# 2     Operação contratual interna
# 3     Operação contratual interna
# 4     Operação contratual interna
# ...                           ...
# 4995  Operação contratual interna
# 4996  Operação contratual interna
# 4997  Operação contratual interna
# 4998  Operação contratual interna
# 4999  Operação contratual interna
#
#                                              finalidade  \
# 0                                               Provias
# 1                                        Infraestrutura
# 2     Aquisição de terrenos, imóveis e/ou construção...
# 3                                   PAC - Contrapartida
# 4                                        Infraestrutura
# ...                                                 ...
# 4995     Aquisição de máquinas, equipamentos e veículos
# 4996         Regularização de Dívida - Energia Elétrica
# 4997                                            Provias
# 4998     Aquisição de máquinas, equipamentos e veículos
# 4999                            Renegociação de dívidas
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996              Empresa Não Estatal
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999                  Empresa Estatal
#
#                                                  credor moeda        valor  \
# 0                                   Banco do Brasil S/A  Real    660000.00
# 1     Agência de Fomento do Estado de Santa Catarina...  Real    600000.00
# 2                      Agência de Fomento do Paraná S/A  Real    120000.00
# 3                                   Banco do Brasil S/A  Real  10878520.29
# 4          Banco de Desenvolvimento de Minas Gerais S/A  Real    890000.00
# ...                                                 ...   ...          ...
# 4995                   Agência de Fomento do Paraná S/A  Real    600000.00
# 4996                      Companhia Energética de Goiás  Real   5600170.56
# 4997                                Banco do Brasil S/A  Real    613800.00
# 4998  Agência de Fomento do Estado de Santa Catarina...  Real    415000.00
# 4999               Companhia Riograndense de Saneamento  Real    655804.95
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    1                      0  15/06/2007
# 1                    0                      0  22/10/2007
# 2                    1                      0  19/04/2006
# 3                    1                      0  08/08/2014
# 4                    1                      0  17/04/2014
# ...                ...                    ...         ...
# 4995                 1                      0  11/09/2013
# 4996                 1                      0  26/09/2023
# 4997                 0                      0  07/11/2007
# 4998                 1                      0  18/03/2004
# 4999                 1                      0  03/08/2007
#
# [5000 rows x 18 columns]

# %%
df_mun_rj['uf'].value_counts()
# Out:
# uf
# PR    1075
# MG     904
# RS     764
# SC     619
# SP     556
# BA     195
# GO      98
# MT      82
# CE      82
# MS      68
# RJ      66
# PE      63
# ES      52
# PA      48
# TO      45
# PI      39
# MA      36
# PB      35
# RN      32
# AL      32
# RO      29
# SE      23
# AM      20
# AC      16
# DF      12
# RR       5
# AP       4
# Name: count, dtype: int64

# %%
# 2) Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?

status_mun_rj = df_mun_rj.status.value_counts()

print('Os três status das solicitações mais frequentes na base de dados são:\n')
for i in range(3):
    print(f'{i+1}º {status_mun_rj.index[i]}: {status_mun_rj[i]}')
# Out:
# Os três status das solicitações mais frequentes na base de dados são:
#
# 1º Deferido: 2776
# 2º Deferido (PVL-IF): 958
# 3º Arquivado: 447
# C:\Users\gusta\AppData\Local\Temp\ipykernel_22792\1469882077.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f'{i+1}º {status_mun_rj.index[i]}: {status_mun_rj[i]}')

# %%
# 3) Construa uma nova variável que contenha o ano do status. 
#    Observe que data_status vem como tipo object no DataFrame. 
#    Dica: você pode usar o método .str para transformar o tipo da variável em string, 
#    em seguida um método como slice() ou split().

# Método slice():
df_mun_rj['ano'] = df_mun_rj['data_status'].str.slice(-4,None)

# Método split():
# df_mun_rj['ano'] = df_mun_rj['data_status'].str.split('/').str[-1]

df_mun_rj
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0         15132        Município  Santa Vitória do Palmar   4317301  RS
# 1         16977        Município             Major Vieira   4210308  SC
# 2         15193        Município                   Loanda   4113502  PR
# 3          9178        Município    São José do Rio Preto   3549805  SP
# 4         10334        Município                   Pompéu   3152006  MG
# ...         ...              ...                      ...       ...  ..
# 4995       8775        Município          Salto do Lontra   4123006  PR
# 4996       8800        Município                    Iporá   5210208  GO
# 4997      12902        Município                 Alexânia   5200308  GO
# 4998      14294        Município            Rio das Antas   4214409  SC
# 4999      14333        Município                   Esteio   4307708  RS
#
#      num_pvl        status          num_processo        data_protocolo  \
# 0       None      Deferido  19406.000145/2007-51  2007-06-14T03:00:00Z
# 1       None      Deferido  19406.000389/2007-33  2007-10-08T03:00:00Z
# 2       None      Deferido  19406.000152/2005-91  2006-03-29T03:00:00Z
# 3       None      Deferido  17944.000919/2014-50  2014-07-14T03:00:00Z
# 4       None      Deferido  17944.001173/2013-11  2014-03-14T03:00:00Z
# ...      ...           ...                   ...                   ...
# 4995    None      Deferido  17944.000839/2013-13  2013-08-21T03:00:00Z
# 4996    None  Regularizado  17944.000843/2009-03  2023-07-28T03:00:00Z
# 4997    None     Arquivado  17944.001845/2006-69  2007-07-02T03:00:00Z
# 4998    None      Deferido  19406.000052/2004-83  2004-02-27T03:00:00Z
# 4999    None      Deferido  19406.000056/2007-12  2007-07-18T03:00:00Z
#
#                     tipo_operacao  \
# 0     Operação contratual interna
# 1     Operação contratual interna
# 2     Operação contratual interna
# 3     Operação contratual interna
# 4     Operação contratual interna
# ...                           ...
# 4995  Operação contratual interna
# 4996  Operação contratual interna
# 4997  Operação contratual interna
# 4998  Operação contratual interna
# 4999  Operação contratual interna
#
#                                              finalidade  \
# 0                                               Provias
# 1                                        Infraestrutura
# 2     Aquisição de terrenos, imóveis e/ou construção...
# 3                                   PAC - Contrapartida
# 4                                        Infraestrutura
# ...                                                 ...
# 4995     Aquisição de máquinas, equipamentos e veículos
# 4996         Regularização de Dívida - Energia Elétrica
# 4997                                            Provias
# 4998     Aquisição de máquinas, equipamentos e veículos
# 4999                            Renegociação de dívidas
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996              Empresa Não Estatal
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999                  Empresa Estatal
#
#                                                  credor moeda        valor  \
# 0                                   Banco do Brasil S/A  Real    660000.00
# 1     Agência de Fomento do Estado de Santa Catarina...  Real    600000.00
# 2                      Agência de Fomento do Paraná S/A  Real    120000.00
# 3                                   Banco do Brasil S/A  Real  10878520.29
# 4          Banco de Desenvolvimento de Minas Gerais S/A  Real    890000.00
# ...                                                 ...   ...          ...
# 4995                   Agência de Fomento do Paraná S/A  Real    600000.00
# 4996                      Companhia Energética de Goiás  Real   5600170.56
# 4997                                Banco do Brasil S/A  Real    613800.00
# 4998  Agência de Fomento do Estado de Santa Catarina...  Real    415000.00
# 4999               Companhia Riograndense de Saneamento  Real    655804.95
#
#       pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 0                    1                      0  15/06/2007  2007
# 1                    0                      0  22/10/2007  2007
# 2                    1                      0  19/04/2006  2006
# 3                    1                      0  08/08/2014  2014
# 4                    1                      0  17/04/2014  2014
# ...                ...                    ...         ...   ...
# 4995                 1                      0  11/09/2013  2013
# 4996                 1                      0  26/09/2023  2023
# 4997                 0                      0  07/11/2007  2007
# 4998                 1                      0  18/03/2004  2004
# 4999                 1                      0  03/08/2007  2007
#
# [5000 rows x 19 columns]

# %%
# 4) Indique a frequência de cada ano do campo construído no item (3).

df_mun_rj['ano'].value_counts().sort_index(ascending=True)
# Out:
# ano
# 2002    131
# 2003    114
# 2004    190
# 2005     32
# 2006    280
# 2007    327
# 2008    492
# 2009    209
# 2010    349
# 2011    249
# 2012    241
# 2013    232
# 2014    242
# 2015     80
# 2016    114
# 2017    139
# 2018    169
# 2019    259
# 2020    190
# 2021    231
# 2022    248
# 2023    321
# 2024    161
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# 1) Faça uma função em Python que recebe como argumento o UF da consulta 
#    e o tipo de interessado ('Estado'ou Município), 
#    e que devolve os dados da consulta no formato DataFrame.

def consultar_PVL(uf:str='SP', tipo_interessado:str='Estado') -> pd.DataFrame:
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={}&tipo_interessado={}'.format(
        uf, 
        tipo_interessado)
    r_uf = requests.get(url)  
    return pd.DataFrame(r_uf.json()['items'])

consultar_PVL('RJ', 'Município')
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        27100        Município  Rio de Janeiro   3304557  RJ
# 1        60630        Município  Miguel Pereira   3302908  RJ
# 2        44142        Município          Paraty   3303807  RJ
# 3        34098        Município         Resende   3304201  RJ
# 4        65965        Município     Barra Mansa   3300407  RJ
# ..         ...              ...             ...       ...  ..
# 259       6628        Município    Belford Roxo   3300456  RJ
# 260      11315        Município          Maricá   3302700  RJ
# 261       7535        Município    Belford Roxo   3300456  RJ
# 262      12870        Município         Niterói   3303302  RJ
# 263       5180        Município     Nova Iguaçu   3303500  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.002429/2017-78                     Arquivado por decurso de prazo
# 1    PVL02.005562/2022-43                                           Deferido
# 2    PVL02.000434/2021-22                                  Deferido (PVL-IF)
# 3    PVL02.003089/2019-64                                  Deferido (PVL-IF)
# 4    PVL02.002790/2023-42                                           Deferido
# ..                    ...                                                ...
# 259                  None                                       Regularizado
# 260                  None                                           Deferido
# 261                  None                                          Arquivado
# 262                  None  Encaminhado à PGFN com manifestação técnica fa...
# 263                  None                                           Deferido
#
#              num_processo        data_protocolo  \
# 0    17944.103668/2017-15  2018-07-31T21:50:09Z
# 1    17944.102601/2022-12  2022-09-02T18:21:45Z
# 2                    None                  None
# 3                    None                  None
# 4    17944.103582/2023-22  2023-08-21T17:00:17Z
# ..                    ...                   ...
# 259  17944.000397/2010-62  2014-10-20T02:00:00Z
# 260  17944.001410/2010-09  2011-01-10T02:00:00Z
# 261  17944.000601/2010-45  2010-11-16T02:00:00Z
# 262  17944.001832/2014-08  2016-03-16T03:00:00Z
# 263  17944.000053/2007-58  2007-07-27T03:00:00Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1                          Operação contratual interna
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4                          Operação contratual interna
# ..                                                 ...
# 259                        Operação contratual interna
# 260                        Operação contratual interna
# 261                        Operação contratual interna
# 262  Operação contratual externa (com garantia da U...
# 263                        Operação contratual interna
#
#                                      finalidade  \
# 0                                Infraestrutura
# 1                                Infraestrutura
# 2                                Infraestrutura
# 3                             Aporte de capital
# 4                                Multissetorial
# ..                                          ...
# 259  Regularização de Dívida - Energia Elétrica
# 260                                        PMAT
# 261                    PAC - Pró-Moradia - 2009
# 262                 Desenvolvimento sustentável
# 263                                       PNAFM
#
#                               tipo_credor  \
# 0         Instituição Financeira Nacional
# 1         Instituição Financeira Nacional
# 2         Instituição Financeira Nacional
# 3         Instituição Financeira Nacional
# 4         Instituição Financeira Nacional
# ..                                    ...
# 259                   Empresa Não Estatal
# 260       Instituição Financeira Nacional
# 261       Instituição Financeira Nacional
# 262  Instituição Financeira Internacional
# 263       Instituição Financeira Nacional
#
#                                                 credor          moeda  \
# 0                              Caixa Econômica Federal           Real
# 1       Agência de Fomento do Estado do Rio de Janeiro           Real
# 2                                  Banco do Brasil S/A           Real
# 3                              Caixa Econômica Federal           Real
# 4       Agência de Fomento do Estado do Rio de Janeiro           Real
# ..                                                 ...            ...
# 259               Light - Serviços de Eletricidade S/A           Real
# 260  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 261                            Caixa Econômica Federal           Real
# 262                       Corporação Andina de Fomento  Dólar dos EUA
# 263                            Caixa Econômica Federal           Real
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    1.000000e+08                 0                      0  07/01/2019
# 1    1.956000e+07                 0                      1  08/09/2022
# 2    4.652519e+06                 0                      1  20/07/2021
# 3    4.000000e+06                 0                      1  27/09/2019
# 4    4.000000e+07                 0                      1  28/08/2023
# ..            ...               ...                    ...         ...
# 259  5.576878e+06                 0                      0  30/10/2014
# 260  1.051389e+07                 1                      0  19/01/2011
# 261  5.588982e+07                 0                      0  27/12/2010
# 262  1.000000e+08                 0                      0  28/03/2016
# 263  1.130667e+07                 1                      0  02/08/2007
#
# [264 rows x 18 columns]

# %%
# 2) Quantas solicitações para o Estado podem ser consultadas para Minas Gerais 
#    com status em 'Arquivado por decurso de prazo' estão registradas?

df_estado_mg = consultar_PVL('MG', 'Estado')
print("Quantidade de solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':")
print(df_estado_mg[df_estado_mg['status'] == 'Arquivado por decurso de prazo'].shape[0])
# Out:
# Quantidade de solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':
# 1

# %%
# 3) Qual é o município da Bahia com mais solicitações deferidas?

df_estado_ba = consultar_PVL('BA', 'Município')
print('O município da Bahia com mais solicitões deferidas:')
print('{} com {} solicitações deferidas.'.format(
    df_estado_ba['interessado'].value_counts().index[0].upper(), 
    df_estado_ba['interessado'].value_counts()[0]))
# Out:
# O município da Bahia com mais solicitões deferidas:
# CAMAÇARI com 20 solicitações deferidas.
# C:\Users\gusta\AppData\Local\Temp\ipykernel_22792\2335010623.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_estado_ba['interessado'].value_counts()[0]))

# %%
# 4) Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'.

df_pvls_estado_ba = consultar_PVL('BA', 'Estado')
df_pvls_estado_ba.to_csv('pvls_estado_ba.csv', index=False)
